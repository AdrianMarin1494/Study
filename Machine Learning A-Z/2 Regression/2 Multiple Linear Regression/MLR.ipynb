# %% [markdown]
# ## Multiple Linear Regression
#
# Formula:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Intuition
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Dummy variables
#
# ![image-2.png](attachment:image-2.png)
