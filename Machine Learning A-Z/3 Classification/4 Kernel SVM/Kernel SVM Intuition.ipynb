# %% [markdown]
# We have a set of observations, which belongs to different classes and the point is to find the decision boundary between them so any future observation could be indentified which class it belongs. What happens when we canno t find the boundary, when the data is not liniarly separable?
# We can add an extra dimension to our dataset and make the data linearly separable.

# %% [markdown]
# ## Mapping to a higher dimension
#
# We can apply a mapping function to add an extra dimension to our dataset.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# Mapping to a hgiher dimmensional space can be highly compute-intensive.

# %% [markdown]
# ## The kernel trick
#
# We can use the Gaussian RBF kernel

# %% [markdown]
# ## Types of Kernel functions
#
# - Gaussian RBF Kernel
# - Sigmoid Kernel
# - Polynomial Kernel
